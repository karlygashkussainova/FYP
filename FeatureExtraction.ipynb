# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
import numpy as np
from scipy import ndimage
from numpy import asarray
from scipy.stats import skew

# %% [markdown]
# ## Read Image

# %%
img = mpimg.imread('1-Copy1.gif') 
plt.imshow(img)

# %% [markdown]
# ## Var, SD, Median, Mode

# %%
data = asarray(img)
#print(type(data))
ndimage.variance(data)
# Out:
# 11260.790697600693

# %%
ndimage.standard_deviation(data)
# Out:
# 106.11687282237774

# %%
ndimage.mean(data)
# Out:
# 87.19464111328125

# %%
ndimage.median(data)
# Out:
# 19.0

# %%
ndimage.center_of_mass(data)
# Out:
# (261.55809546009124, 251.6945733296374, 2.462245825799718)

# %% [markdown]
# # Skewness

# %%
skew(data, axis=2)
# Out:
# array([[1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054],
#        [1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054],
#        [1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054],
#        ...,
#        [1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054],
#        [1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054],
#        [1.15470054, 1.15470054, 1.15470054, ..., 1.15470054, 1.15470054,
#         1.15470054]])

# %%
import scipy

dat = data.T
a=scipy.stats.skew(dat,axis=0)
print(a)
# Out:
# [[1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]
#  [1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]
#  [1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]
#  ...
#  [1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]
#  [1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]
#  [1.15470054 1.15470054 1.15470054 ... 1.15470054 1.15470054 1.15470054]]

# %% [markdown]
# ## Kurtosis

# %%
from scipy.stats import kurtosis
kurtosis(img)
# Out:
# array([[-3., -3., -3., -3.],
#        [-3., -3., -3., -3.],
#        [-3., -3., -3., -3.],
#        ...,
#        [-3., -3., -3., -3.],
#        [-3., -3., -3., -3.],
#        [-3., -3., -3., -3.]])
